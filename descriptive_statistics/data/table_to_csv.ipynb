# %%
import psycopg2
import pandas as pd

# %% [markdown]
# # Retrieve data from database

# %%
conn = psycopg2.connect(database='full_STUPS',
                        user='postgres',
                        host='localhost',
                        password='postgres',
                        port=5432)
cur = conn.cursor()
cur.execute('SELECT * from echantillon_propriete')
samples = cur.fetchall()
conn.close()
colnames = [desc[0] for desc in cur.description]

df = pd.DataFrame(list(samples), columns=colnames)
display(df)
# Out:
#           id _3_4_methylenedioxyethylamphetamine  \
# 0          1                                None
# 1          2                                None
# 2          3                                None
# 3          4                                None
# 4          5                                None
# ...      ...                                 ...
# 20068  23910                                None
# 20069  23911                                None
# 20070  23918                                None
# 20071  23919                                None
# 20072  23920                                None
#
#       _3_4_methylene_dioxy_methylamphetamine _3_4_methylenedioxyphenylacetone  \
# 0                                       None                             None
# 1                                       None                             None
# 2                                       None                             None
# 3                                       None                             None
# 4                                       None                             None
# ...                                      ...                              ...
# 20068                                   None                             None
# 20069                                   None                             None
# 20070                                   None                             None
# 20071                                   None                             None
# 20072                                   None                             None
#
#       _4f_mdmb_butinaca _5f_adb _5f_mdmb_pica abime acetylcodeine  \
# 0                  None    None          None  None          None
# 1                  None    None          None  None          None
# 2                  None    None          None  None          None
# 3                  None    None          None  None          None
# 4                  None    None          None  None          None
# ...                 ...     ...           ...   ...           ...
# 20068              None    None          None  None          None
# 20069              None    None          None  None          None
# 20070              None    None          None  None          None
# 20071              None    None          None  None          None
# 20072              None    None          None  None          None
#
#       acetylthebaol  ... terephtalates tetracaine tramadol  \
# 0              None  ...          None       None     None
# 1              None  ...          None       None     None
# 2              None  ...          None       None     None
# 3              None  ...          None       None     None
# 4              None  ...          None       None     None
# ...             ...  ...           ...        ...      ...
# 20068          None  ...          None       None     None
# 20069          None  ...          None       None     None
# 20070          None  ...          None       None     None
# 20071          None  ...          None       None     None
# 20072          None  ...          None       None     None
#
#       trans_cinnamoylcocaine tropacocaine             type_drogue  uree  \
# 0                       None         None                  Divers  None
# 1                       None         None  Amphétamine et dérivés  None
# 2                       None         None                Cannabis  None
# 3                       None         None                 Héroïne  None
# 4                       None         None                 Héroïne  None
# ...                      ...          ...                     ...   ...
# 20068                   None         None                 Héroïne  None
# 20069                   None         None                 Héroïne  None
# 20070                   None         None                 Cocaïne  None
# 20071                   None         None                 Cocaïne  None
# 20072                   None         None                 Cocaïne  None
#
#       valine vanilline visqueux
# 0       None      None     None
# 1       None      None     None
# 2       None      None     None
# 3       None      None     None
# 4       None      None     None
# ...      ...       ...      ...
# 20068   None      None     None
# 20069   None      None     None
# 20070   None      None     None
# 20071   None      None     None
# 20072   None      None     None
#
# [20073 rows x 116 columns]

# %% [markdown]
# # Export to csv

# %% [markdown]
# ## Export full csv

# %%
df.to_csv('full.csv')

# %% [markdown]
# ## Export Cannabis csv

# %%
quanti_cols = ['cannabidiol', 'cannabigerol', 'cannabinol', 'cbd', 'cbn', 'delta9_tetrahydrocannabinol', 'epaisseur', 'hauteur', 'largeur', 'logo', 'longueur', 'masse', 'taux_cbd', 'taux_cbn', 'visqueux']
boolean_cols = ['abime', 'visqueux', 'etiquette', 'logo']

cannabis_df = df.copy()
cannabis_df = cannabis_df.loc[cannabis_df['type_drogue'] == 'Cannabis']

cannabis_df.dropna(how='all', axis=1, inplace=True) 
cannabis_df.reset_index(drop=True, inplace=True)

cannabis_df[quanti_cols] = cannabis_df[quanti_cols].fillna(0)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].fillna(False)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace('Non', False)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace('0', False)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace(0, False)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace('Oui', True)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace('1', True)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace(1, True)
# cannabis_df['presentation'] = cannabis_df['presentation'].fillna('')

# cannabis_df = cannabis_df[(cannabis_df['cbd'] != 0) | (cannabis_df['cbn'] != 0)]
# cannabis_df = cannabis_df[(cannabis_df['presentation'] != '')]

cannabis_df = cannabis_df.drop(columns=['cannabigerol', 'presentation', 'couleur', 'forme', 'cbd', 'cbn', 'type_drogue', 'logo', 'couleur_exterieur', 'couleur_exterieur_1', 'couleur_interieur',  'description_de_l_objet', 'numero_echantillon', 'ovule', 'nom_de_logo', 'secabilite_recto', 'secabilite_verso'])

display(cannabis_df)
cannabis_df.to_csv('cannabis.csv', index=False)
print(f'Cannabis dataframe shape {cannabis_df.shape}' )
# Out:
#          id  abime cannabidiol cannabinol delta9_tetrahydrocannabinol  \
# 0         3  False           0          0                           8
# 1        29  False           0          0                        13.5
# 2        30  False           0          0                        13.5
# 3        32  False           0          0                        20.4
# 4        33  False           0          0                        30.7
# ...     ...    ...         ...        ...                         ...
# 6240  14252  False           0          0                        11.1
# 6241  14255  False           0          0                        39.4
# 6242  14256  False           0          0                        40.4
# 6243  14260  False           0          0                          31
# 6244  14261  False           0          0                          23
#
#      epaisseur  etiquette hauteur largeur longueur masse taux_cbd taux_cbn  \
# 0            0      False       0       0        0     0        0        0
# 1            0      False       0       0        0     0        0        0
# 2            0      False       0       0        0     0        0        0
# 3            0      False       0       0        0   5.2      1.6      1.4
# 4            0      False       0       0        0   3.1      1.5        0
# ...        ...        ...     ...     ...      ...   ...      ...      ...
# 6240         0      False       0       0        0     0        0        0
# 6241        30       True       0      46       90  99.1        0        0
# 6242         0      False       0       0        0     0        0        0
# 6243         0      False       0       0        0     0        1        0
# 6244         0      False       0       0        0     0        2        1
#
#       visqueux
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 6240     False
# 6241     False
# 6242     False
# 6243     False
# 6244     False
#
# [6245 rows x 14 columns]
# Cannabis dataframe shape (6245, 14)

# %% [markdown]
# ## Export Héroïne csv

# %%
heroine_df = df.copy()
heroine_df = heroine_df.loc[heroine_df['type_drogue'] == 'Héroïne']
heroine_df.dropna(how='all', axis=1, inplace=True) 
heroine_df.reset_index(drop=True, inplace=True)
heroine_df.to_csv('heroine.csv', index=False)
print(f'Heroine dataframe shape {heroine_df.shape}' )
# Out:
# Heroine dataframe shape (2318, 29)

# %% [markdown]
# ## Export Cocaïne csv

# %%
cocaine_df = df.copy()
cocaine_df = cocaine_df.loc[cocaine_df['type_drogue'] == 'Cocaïne']
cocaine_df.dropna(how='all', axis=1, inplace=True) 
cocaine_df.reset_index(drop=True, inplace=True)
cocaine_df.to_csv('../data/cocaine.csv', index=False)
print(f'Cocaine dataframe shape {cocaine_df.shape}' )
# Out:
# Cocaine dataframe shape (9143, 77)

# %% [markdown]
# ## Export Amphétamine et dérivés csv

# %%
amphet_df = df.copy()
amphet_df = amphet_df.loc[amphet_df['type_drogue'] == 'Amphétamine et dérivés']
amphet_df.dropna(how='all', axis=1, inplace=True) 
amphet_df.reset_index(drop=True, inplace=True)
amphet_df.to_csv('amphet.csv', index=False)
print(f'Amphet dataframe shape {amphet_df.shape}')
# Out:
# Amphet dataframe shape (1136, 26)

# %% [markdown]
# ## Export Divers csv

# %%
divers_df = df.copy()
divers_df = divers_df.loc[divers_df['type_drogue'] == 'Divers']
divers_df.dropna(how='all', axis=1, inplace=True) 
divers_df.reset_index(drop=True, inplace=True)
divers_df.to_csv('divers.csv', index=False)
print(f'Amphet dataframe shape {divers_df.shape}')
# Out:
# Amphet dataframe shape (1231, 63)
