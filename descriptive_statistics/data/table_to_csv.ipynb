# %%
import psycopg2
import pandas as pd

# %% [markdown]
# # Retrieve data from database

# %%
conn = psycopg2.connect(database='full_STUPS',
                        user='postgres',
                        host='localhost',
                        password='postgres',
                        port=5432)
cur = conn.cursor()
cur.execute('SELECT * from echantillon_propriete')
samples = cur.fetchall()
conn.close()
colnames = [desc[0] for desc in cur.description]

df = pd.DataFrame(list(samples), columns=colnames)
display(df)
# Out:
#           id _3_4_methylenedioxyethylamphetamine  \
# 0          1                                None
# 1          2                                None
# 2          3                                None
# 3          4                                None
# 4          5                                None
# ...      ...                                 ...
# 20068  23910                                None
# 20069  23911                                None
# 20070  23918                                None
# 20071  23919                                None
# 20072  23920                                None
#
#       _3_4_methylene_dioxy_methylamphetamine _5f_adb _5f_mdmb_pica abime  \
# 0                                       None    None          None  None
# 1                                       None    None          None  None
# 2                                       None    None          None  None
# 3                                       None    None          None  None
# 4                                       None    None          None  None
# ...                                      ...     ...           ...   ...
# 20068                                   None    None          None  None
# 20069                                   None    None          None  None
# 20070                                   None    None          None  None
# 20071                                   None    None          None  None
# 20072                                   None    None          None  None
#
#       acide_4_hydroxybutanoique adb_butinaca amphetamine buprenorphine  ...  \
# 0                          None         None        None          None  ...
# 1                          None         None        None          None  ...
# 2                          None         None        None          None  ...
# 3                          None         None        None          None  ...
# 4                          None         None        None          None  ...
# ...                         ...          ...         ...           ...  ...
# 20068                      None         None        None          None  ...
# 20069                      None         None        None          None  ...
# 20070                      None         None        None          None  ...
# 20071                      None         None        None          None  ...
# 20072                      None         None        None          None  ...
#
#       o6_monoacetylmorphine ovule paracetamol phenacetine presentation  \
# 0                      None     0        None        None         None
# 1                      None     0        None        None         None
# 2                      None  None        None        None     Sommités
# 3                      None     0        None        None         None
# 4                      None     0        None        None         None
# ...                     ...   ...         ...         ...          ...
# 20068                  None     0        None        None         None
# 20069                  None     0        None        None         None
# 20070                  None     0        None        None         None
# 20071                  None     0        None        None         None
# 20072                  None     0        None        None         None
#
#       procaine secabilite_recto secabilite_verso             type_drogue  \
# 0         None             None             None                  Divers
# 1         None             None             None  Amphétamine et dérivés
# 2         None             None             None                Cannabis
# 3         None             None             None                 Héroïne
# 4         None             None             None                 Héroïne
# ...        ...              ...              ...                     ...
# 20068     None             None             None                 Héroïne
# 20069     None             None             None                 Héroïne
# 20070     None             None             None                 Cocaïne
# 20071     None             None             None                 Cocaïne
# 20072     None             None             None                 Cocaïne
#
#       visqueux
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ...        ...
# 20068     None
# 20069     None
# 20070     None
# 20071     None
# 20072     None
#
# [20073 rows x 54 columns]

# %% [markdown]
# # Export to csv

# %% [markdown]
# ## Export full csv

# %%
df.to_csv('full.csv')

# %% [markdown]
# ## Export Cannabis csv

# %%
quanti_cols = ['cannabidiol', 'cannabigerol', 'cannabinol', 'cbd', 'cbn', 'delta9_tetrahydrocannabinol', 'epaisseur', 'hauteur', 'largeur', 'logo', 'longueur', 'masse', 'taux_cbd', 'taux_cbn', 'visqueux']
boolean_cols = ['abime', 'visqueux', 'etiquette', 'logo']

cannabis_df = df.copy()
cannabis_df = cannabis_df.loc[cannabis_df['type_drogue'] == 'Cannabis']

cannabis_df.dropna(how='all', axis=1, inplace=True) 
cannabis_df.reset_index(drop=True, inplace=True)

cannabis_df[quanti_cols] = cannabis_df[quanti_cols].fillna(0)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].fillna(False)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace('Non', False)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace('0', False)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace(0, False)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace('Oui', True)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace('1', True)
cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace(1, True)
# cannabis_df['presentation'] = cannabis_df['presentation'].fillna('')

# cannabis_df = cannabis_df[(cannabis_df['cbd'] != 0) | (cannabis_df['cbn'] != 0)]
# cannabis_df = cannabis_df[(cannabis_df['presentation'] != '')]

cannabis_df = cannabis_df.drop(columns=['cannabigerol', 'couleur', 'forme', 'cbd', 'cbn', 'type_drogue', 'logo', 'couleur_exterieur', 'couleur_exterieur_1', 'couleur_interieur',  'description_de_l_objet', 'numero_echantillon', 'ovule', 'nom_de_logo', 'secabilite_recto', 'secabilite_verso'])

display(cannabis_df)
cannabis_df.to_csv('cannabis.csv', index=False)
print(f'Cannabis dataframe shape {cannabis_df.shape}' )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 10
#       7 cannabis_df.dropna(how='all', axis=1, inplace=True)
#       8 cannabis_df.reset_index(drop=True, inplace=True)
# ---> 10 cannabis_df[quanti_cols] = cannabis_df[quanti_cols].fillna(0)
#      11 cannabis_df[boolean_cols] = cannabis_df[boolean_cols].fillna(False)
#      12 cannabis_df[boolean_cols] = cannabis_df[boolean_cols].replace('Non', False)
#
# File c:\Users\Sebastien GUILLEMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Sebastien GUILLEMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Sebastien GUILLEMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['cannabigerol', 'cbd', 'cbn', 'taux_cbd', 'taux_cbn'] not in index"

# %% [markdown]
# ## Export Héroïne csv

# %%
heroine_df = df.copy()
heroine_df = heroine_df.loc[heroine_df['type_drogue'] == 'Héroïne']
heroine_df.dropna(how='all', axis=1, inplace=True) 
heroine_df.reset_index(drop=True, inplace=True)
heroine_df.to_csv('heroine.csv', index=False)
print(f'Heroine dataframe shape {heroine_df.shape}' )

# %% [markdown]
# ## Export Cocaïne csv

# %%
cocaine_df = df.copy()
cocaine_df = cocaine_df.loc[cocaine_df['type_drogue'] == 'Cocaïne']
cocaine_df.dropna(how='all', axis=1, inplace=True) 
cocaine_df.reset_index(drop=True, inplace=True)
cocaine_df.to_csv('../data/cocaine.csv', index=False)
print(f'Cocaine dataframe shape {cocaine_df.shape}' )

# %% [markdown]
# ## Export Amphétamine et dérivés csv

# %%
amphet_df = df.copy()
amphet_df = amphet_df.loc[amphet_df['type_drogue'] == 'Amphétamine et dérivés']
amphet_df.dropna(how='all', axis=1, inplace=True) 
amphet_df.reset_index(drop=True, inplace=True)
amphet_df.to_csv('amphet.csv', index=False)
print(f'Amphet dataframe shape {amphet_df.shape}')

# %% [markdown]
# ## Export Divers csv

# %%
divers_df = df.copy()
divers_df = divers_df.loc[divers_df['type_drogue'] == 'Divers']
divers_df.dropna(how='all', axis=1, inplace=True) 
divers_df.reset_index(drop=True, inplace=True)
divers_df.to_csv('divers.csv', index=False)
print(f'Amphet dataframe shape {divers_df.shape}')
