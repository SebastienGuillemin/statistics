# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.datasets import fetch_openml
from sklearn.cluster import KMeans
import pandas as pd

# %%
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)

# %%
X = X[:2500]
y = y[:2500]
print(X.shape)
# Out:
# (2500, 784)

# %%
tsne = TSNE(n_components=2, perplexity=50)
embedding = tsne.fit_transform(X)
plt.scatter(embedding[:,0], embedding[:,1])
plt.show()

# %%
nb_clusters = 10
kmeans = KMeans(n_clusters=nb_clusters, random_state=0, n_init="auto").fit(embedding)
labels = kmeans.predict(embedding)

# %%
embedding_df = pd.DataFrame({'x': embedding[:, 0], 'y': embedding[:, 1], 'label': labels})
fig, ax = plt.subplots(1)
sns.color_palette("bright")
sns.scatterplot(x="x", y="y", data=embedding_df, hue='label', ax=ax, s=30, palette=sns.color_palette('bright', n_colors=nb_clusters))

lim = (embedding.min()-5, embedding.max()+5)
ax.set_xlim(lim)
ax.set_ylim(lim)
ax.set_aspect('equal')
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.0)
